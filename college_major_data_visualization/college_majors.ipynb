# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
recent_grads = pd.read_csv("recent-grads.csv")
first_row = recent_grads.iloc[0]
#first_row
#recent_grads.head()
#recent_grads.tail()
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
#initial rows = 173
raw_data_count = recent_grads.shape[0]
raw_data_count
# Out:
# 173

# %%
# drop rows with NA and count new number of rows
recent_grads = recent_grads.dropna()
cleaned_data_count = recent_grads.shape[0]
print(cleaned_data_count)
# Out:
# 172

# %%
recent_grads.plot(x = "Sample_size", y = "Median", kind = "scatter")

# %%
recent_grads.plot(x = "Sample_size", y = "Unemployment_rate", kind = "scatter")

# %%
recent_grads.plot(x = "Full_time", y = "Median", kind = "scatter")

# %%
recent_grads.plot(x = "ShareWomen", y = "Unemployment_rate", kind = "scatter")

# %%
recent_grads.plot(x = "Men", y = "Median", kind = "scatter")

# %%
recent_grads.plot(x = "Women", y = "Median", kind = "scatter")

# %% [markdown]
# ## From the above plots, it does not appear that students in more popular majors make more money.  It also appears that there is no correlation between major popularity and unemployment rate.

# %%
recent_grads["Sample_size"].hist(bins = 3)

# %%
recent_grads["Median"].hist(bins = 3)

# %%
recent_grads["Employed"].hist(bins = 3, range = (0,350000))

# %%
recent_grads["Full_time"].hist(bins = 3)

# %%
recent_grads["ShareWomen"].hist()

# %%
recent_grads["Unemployment_rate"].hist()

# %%
recent_grads["Men"].hist(bins = 3)

# %%
recent_grads["Women"].hist(bins = 3)

# %% [markdown]
# ## The percent of majors that are predominantly male vs. female is roughly 50%.  The most common median salary range by far is 20000-50000

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(recent_grads[["Sample_size", "Median"]], figsize = (10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5425797d68>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f542569b5c0>]], dtype=object)

# %%
scatter_matrix(recent_grads[["Sample_size", "Median", "Unemployment_rate"]], figsize = (10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5425ac3940>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f542588eeb8>]], dtype=object)

# %%
recent_grads["ShareWomen"].head(10).plot.bar(x = "Major", y = "ShareWomen")

# %%
recent_grads["ShareWomen"].tail(10).plot.bar(x = "Major", y = "ShareWomen")

# %%
recent_grads["Unemployment_rate"].head(10).plot.bar(x = "Major", y = "Unemployment_rate")

# %%
recent_grads["Unemployment_rate"].tail(10).plot.bar(x = "Major", y = "Unemployment_rate")
